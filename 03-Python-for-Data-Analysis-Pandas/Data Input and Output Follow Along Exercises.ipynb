# %%
import numpy as np
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Hesti\\Documents\\Learning\\Python for Data Science and Machine Learning Bootcamp\\Py-DS-ML-Bootcamp-master\\Refactored_Py_DS_ML_Bootcamp-master\\03-Python-for-Data-Analysis-Pandas'

# %%
pd.read_csv('example')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df = pd.read_csv('example')

# %%
df.to_csv('My_example_output')

# %%
pd.read_csv('My_example_output', index_col=0)
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('My_example_output', index=False)

# %%
pd.read_csv('My_example_output')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df = pd.read_excel('Excel_Sample.xlsx', index_col=0, sheet_name='Sheet1')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_excel('Excel_Sample2.xlsx', sheet_name='NewSheet')

# %%
data = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
type(data)
# Out:
# list

# %%
data
# Out:
# [                               Bank Name        City  ST   CERT  \
#  0       City National Bank of New Jersey      Newark  NJ  21111
#  1                          Resolute Bank      Maumee  OH  58317
#  2                  Louisa Community Bank      Louisa  KY  58112
#  3                   The Enloe State Bank      Cooper  TX  10716
#  4    Washington Federal Bank for Savings     Chicago  IL  30570
#  ..                                   ...         ...  ..    ...
#  554                   Superior Bank, FSB    Hinsdale  IL  32646
#  555                  Malta National Bank       Malta  OH   6629
#  556      First Alliance Bank & Trust Co.  Manchester  NH  34264
#  557    National State Bank of Metropolis  Metropolis  IL   3815
#  558                     Bank of Honolulu    Honolulu  HI  21029
#
#                     Acquiring Institution       Closing Date       Updated Date
#  0                        Industrial Bank   November 1, 2019  December 19, 2019
# ...

# %%
data[0]
# Out:
#                                Bank Name        City  ST   CERT  \
# 0       City National Bank of New Jersey      Newark  NJ  21111
# 1                          Resolute Bank      Maumee  OH  58317
# 2                  Louisa Community Bank      Louisa  KY  58112
# 3                   The Enloe State Bank      Cooper  TX  10716
# 4    Washington Federal Bank for Savings     Chicago  IL  30570
# ..                                   ...         ...  ..    ...
# 554                   Superior Bank, FSB    Hinsdale  IL  32646
# 555                  Malta National Bank       Malta  OH   6629
# 556      First Alliance Bank & Trust Co.  Manchester  NH  34264
# 557    National State Bank of Metropolis  Metropolis  IL   3815
# 558                     Bank of Honolulu    Honolulu  HI  21029
#
#                    Acquiring Institution       Closing Date       Updated Date
# 0                        Industrial Bank   November 1, 2019  December 19, 2019
# ...

# %%
type(data[0])
# Out:
# pandas.core.frame.DataFrame

# %%
data[0].head()
# Out:
#                              Bank Name     City  ST   CERT  \
# 0     City National Bank of New Jersey   Newark  NJ  21111
# 1                        Resolute Bank   Maumee  OH  58317
# 2                Louisa Community Bank   Louisa  KY  58112
# 3                 The Enloe State Bank   Cooper  TX  10716
# 4  Washington Federal Bank for Savings  Chicago  IL  30570
#
#                Acquiring Institution       Closing Date       Updated Date
# 0                    Industrial Bank   November 1, 2019  December 19, 2019
# 1                 Buckeye State Bank   October 25, 2019  December 19, 2019
# 2  Kentucky Farmers Bank Corporation   October 25, 2019  December 19, 2019
# 3                 Legend Bank, N. A.       May 31, 2019  December 19, 2019
# 4                 Royal Savings Bank  December 15, 2017      July 24, 2019

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
df.to_sql('my_table', engine)

# %%
sqldf = pd.read_sql('my_table', con=engine)  #con means connection

# %%
sqldf
# Out:
#    index   a   b   c   d
# 0      0   0   1   2   3
# 1      1   4   5   6   7
# 2      2   8   9  10  11
# 3      3  12  13  14  15

# %%
type(sqldf)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(engine)
# Out:
# sqlalchemy.engine.base.Engine
