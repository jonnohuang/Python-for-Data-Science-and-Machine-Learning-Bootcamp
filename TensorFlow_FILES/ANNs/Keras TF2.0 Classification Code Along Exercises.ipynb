# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../DATA/cancer_classification.csv')

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
# mean radius                569 non-null float64
# mean texture               569 non-null float64
# mean perimeter             569 non-null float64
# mean area                  569 non-null float64
# mean smoothness            569 non-null float64
# mean compactness           569 non-null float64
# mean concavity             569 non-null float64
# mean concave points        569 non-null float64
# mean symmetry              569 non-null float64
# mean fractal dimension     569 non-null float64
# radius error               569 non-null float64
# texture error              569 non-null float64
# perimeter error            569 non-null float64
# area error                 569 non-null float64
# smoothness error           569 non-null float64
# compactness error          569 non-null float64
# concavity error            569 non-null float64
# ...

# %%
df.describe().transpose()
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# ...

# %%
sns.countplot(x='benign_0__mal_1',data=df)

# %%
df.corr()['benign_0__mal_1'][:-1].sort_values(ascending=False)
# Out:
# smoothness error           0.067016
# mean fractal dimension     0.012838
# texture error              0.008303
# symmetry error             0.006522
# fractal dimension error   -0.077972
# concavity error           -0.253730
# compactness error         -0.292999
# worst fractal dimension   -0.323872
# mean symmetry             -0.330499
# mean smoothness           -0.358560
# concave points error      -0.408042
# mean texture              -0.415185
# worst symmetry            -0.416294
# worst smoothness          -0.421465
# worst texture             -0.456903
# area error                -0.548236
# perimeter error           -0.556141
# radius error              -0.567134
# worst compactness         -0.590998
# mean compactness          -0.596534
# worst concavity           -0.659610
# mean concavity            -0.696360
# mean area                 -0.708984
# mean radius               -0.730029
# worst area                -0.733825
# mean perimeter            -0.742636
# ...

# %%
plt.figure(figsize=(12,6))
df.corr()['benign_0__mal_1'][:-1].sort_values(ascending=False).plot(kind='bar')

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr())

# %%
X = df.drop('benign_0__mal_1',axis=1).values
y = df['benign_0__mal_1'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense,Dropout

# %%
X_train.shape
# Out:
# (426, 30)

# %%
model = Sequential()

model.add(Dense(30,activation='relu'))

model.add(Dense(15,activation='relu'))

# Binary Classification uses Sigmoid activation function in fnal layer
model.add(Dense(1,activation='sigmoid'))
# Binary Classification uses Binary Cross Entropy in the loss metrics
model.compile(loss='binary_crossentropy',optimizer='adam')

# %%
model.fit(x=X_train,y=y_train,epochs=400,validation_data=(X_test,y_test))
# Out:
# Train on 426 samples, validate on 143 samples
# Epoch 1/400
# 426/426 [==============================] - 1s 2ms/sample - loss: 0.6772 - val_loss: 0.6652
# Epoch 2/400
# 426/426 [==============================] - 0s 145us/sample - loss: 0.6529 - val_loss: 0.6390
# Epoch 3/400
# 426/426 [==============================] - 0s 138us/sample - loss: 0.6249 - val_loss: 0.6101
# Epoch 4/400
# 426/426 [==============================] - 0s 131us/sample - loss: 0.5907 - val_loss: 0.5719
# Epoch 5/400
# 426/426 [==============================] - 0s 145us/sample - loss: 0.5487 - val_loss: 0.5252
# Epoch 6/400
# 426/426 [==============================] - 0s 131us/sample - loss: 0.4978 - val_loss: 0.4646
# Epoch 7/400
# 426/426 [==============================] - 0s 150us/sample - loss: 0.4375 - val_loss: 0.4045
# Epoch 8/400
# 426/426 [==============================] - 0s 148us/sample - loss: 0.3883 - val_loss: 0.3557
# Epoch 9/400
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses
# Out:
#          loss  val_loss
# 0    0.677228  0.665193
# 1    0.652865  0.638972
# 2    0.624943  0.610067
# 3    0.590725  0.571874
# 4    0.548707  0.525244
# ..        ...       ...
# 395  0.017361  0.219059
# 396  0.016966  0.303899
# 397  0.018969  0.225341
# 398  0.019422  0.257986
# 399  0.019855  0.276886
#
# [400 rows x 2 columns]

# %%
losses.plot()

# %% [markdown]
# #### Overfitting occured
# #### EarlyStoping callback needed
# #### Redefine and compile a fresh new model

# %%
model = Sequential()

model.add(Dense(30,activation='relu'))

model.add(Dense(15,activation='relu'))

# Binary Classification uses Sigmoid activation function in fnal layer
model.add(Dense(1,activation='sigmoid'))
# Binary Classification uses Binary Cross Entropy in the loss metrics
model.compile(loss='binary_crossentropy',optimizer='adam')

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
help(EarlyStopping)
# Out:
# Help on class EarlyStopping in module tensorflow.python.keras.callbacks:
#
# class EarlyStopping(Callback)
#  |  EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
#  |
#  |  Stop training when a monitored quantity has stopped improving.
#  |
#  |  Arguments:
#  |      monitor: Quantity to be monitored.
#  |      min_delta: Minimum change in the monitored quantity
#  |          to qualify as an improvement, i.e. an absolute
#  |          change of less than min_delta, will count as no
#  |          improvement.
#  |      patience: Number of epochs with no improvement
#  |          after which training will be stopped.
#  |      verbose: verbosity mode.
#  |      mode: One of `{"auto", "min", "max"}`. In `min` mode,
#  |          training will stop when the quantity
#  |          monitored has stopped decreasing; in `max`
#  |          mode it will stop when the quantity
# ...

# %%
early_stop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=25)

# %%
model.fit(x=X_train,y=y_train,epochs=600,validation_data=(X_test,y_test),
         callbacks=[early_stop])
# Out:
# Train on 426 samples, validate on 143 samples
# Epoch 1/600
# 426/426 [==============================] - 1s 2ms/sample - loss: 0.6873 - val_loss: 0.6654
# Epoch 2/600
# 426/426 [==============================] - 0s 150us/sample - loss: 0.6543 - val_loss: 0.6395
# Epoch 3/600
# 426/426 [==============================] - 0s 152us/sample - loss: 0.6200 - val_loss: 0.6000
# Epoch 4/600
# 426/426 [==============================] - 0s 164us/sample - loss: 0.5791 - val_loss: 0.5580
# Epoch 5/600
# 426/426 [==============================] - 0s 141us/sample - loss: 0.5355 - val_loss: 0.5100
# Epoch 6/600
# 426/426 [==============================] - 0s 157us/sample - loss: 0.4861 - val_loss: 0.4560
# Epoch 7/600
# 426/426 [==============================] - 0s 174us/sample - loss: 0.4325 - val_loss: 0.3999
# Epoch 8/600
# 426/426 [==============================] - 0s 150us/sample - loss: 0.3813 - val_loss: 0.3461
# Epoch 9/600
# ...

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
model_loss.plot()

# %% [markdown]
# #### Dropout Layers

# %%
from tensorflow.keras.layers import Dropout

# %%
model = Sequential()

model.add(Dense(30,activation='relu'))
# add dropout layer.  Typical good dropout rate is 20% to 50%
model.add(Dropout(0.5))

model.add(Dense(15,activation='relu'))
model.add(Dropout(0.5))

# Binary Classification uses Sigmoid activation function in fnal layer
model.add(Dense(1,activation='sigmoid'))
# Binary Classification uses Binary Cross Entropy in the loss metrics
model.compile(loss='binary_crossentropy',optimizer='adam')

# %%
# Same Early Stop setting used
#early_stop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=25)

model.fit(x=X_train,y=y_train,epochs=600,validation_data=(X_test,y_test),
         callbacks=[early_stop])
# Out:
# Train on 426 samples, validate on 143 samples
# Epoch 1/600
# 426/426 [==============================] - 1s 3ms/sample - loss: 0.7332 - val_loss: 0.6907
# Epoch 2/600
# 426/426 [==============================] - 0s 150us/sample - loss: 0.6888 - val_loss: 0.6669
# Epoch 3/600
# 426/426 [==============================] - 0s 150us/sample - loss: 0.6728 - val_loss: 0.6468
# Epoch 4/600
# 426/426 [==============================] - 0s 162us/sample - loss: 0.6668 - val_loss: 0.6282
# Epoch 5/600
# 426/426 [==============================] - 0s 171us/sample - loss: 0.6422 - val_loss: 0.6087
# Epoch 6/600
# 426/426 [==============================] - 0s 169us/sample - loss: 0.6266 - val_loss: 0.5874
# Epoch 7/600
# 426/426 [==============================] - 0s 169us/sample - loss: 0.6208 - val_loss: 0.5656
# Epoch 8/600
# 426/426 [==============================] - 0s 141us/sample - loss: 0.5942 - val_loss: 0.5396
# Epoch 9/600
# ...

# %%
model_losses = pd.DataFrame(model.history.history)

# %%
model_losses.plot()

# %%
# For Classification, predict_classes method is used
predictions = model.predict_classes(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96        55
#            1       0.99      0.97      0.98        88
#
#     accuracy                           0.97       143
#    macro avg       0.97      0.97      0.97       143
# weighted avg       0.97      0.97      0.97       143

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[54  1]
#  [ 3 85]]
