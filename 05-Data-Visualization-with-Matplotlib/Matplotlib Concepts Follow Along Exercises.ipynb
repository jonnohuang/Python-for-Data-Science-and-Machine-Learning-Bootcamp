# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x **2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# FUNCTIONAL
plt.plot(x,y)
plt.show()

# %%
plt.plot(x, y, 'g-')

# %%
plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
plt.subplot(2,4,1)
plt.subplot(2,4,2)
plt.subplot(2,4,3)
plt.subplot(2,4,4)
plt.subplot(2,4,5)
plt.subplot(2,4,8)

# %%
# OO
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes2.plot(y,x)
axes2.set_title('SMALLER PLOT')
axes1.set_title('LARGER PLOT')
# Out:
# Text(0.5, 1.0, 'LARGER PLOT')

# %%
fig,axes = plt.subplots(nrows=1,ncols=3)

#axes.plot(x,y)
#plt.tight_layout()

for current_ax in axes:
    current_ax.plot(x,y)

'''
axes[0].plot(x,y)
axes[0].set_title('First Plot')

axes[1].plot(y,x)
axes[1].set_title('Second Plot')
'''
plt.tight_layout()

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000028633FEC408>,
# ...
#       dtype=object)

# %%
fig = plt.figure(figsize=(6,2),dpi=100)

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,ax = plt.subplots(nrows=2, ncols=1,figsize=(6,2),dpi=100)

#ax = fig.add_axes([0,0,1,1])
ax[0].plot(x,y)
ax[1].plot(y,x)

plt.tight_layout()

# %%
fig.savefig('my_picture.png', dpi=200)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x**2,label='X Squared')
ax.plot(x,x**3,label='X Cubed')


ax.set_title('Title')
ax.set_ylabel('Y Label')
ax.set_xlabel('X Label')

ax.legend(loc=0)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='#000000',lw=10,alpha=0.1,ls='-.',marker='o',ms=20,
       markerfacecolor='yellow',mew=3,mec='red')  #lw = linewidth, ls=linestytle, ms=markersize, mew=markeredgewidth, mec=markeredgeolor

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
len(x)
# Out:
# 11

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=2,ls='--')
ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0, 2)

# %%
plt.scatter(x,y)

# %%
plt.plot(x, x, x, x**2, x, x**3)
